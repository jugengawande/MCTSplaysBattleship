# %% [markdown]
# # Battleship AI Analysis

# %%
from game_physics import * 
from game_variables import Settings as s

import pandas as pd
import numpy as np
import seaborn as sns
import random 

import warnings
warnings.filterwarnings('ignore')

# %%
def run_simulation(iterations, grid_size, fleet, strategy_1, strategy_0):
    player_1_wins = 0       
    player_0_wins = 0
    result = pd.DataFrame(columns=['test', 'player_1_win','player_0_win', 'miss', 'steps'])
    
    s.set_grid_size = grid_size
    s.set_fleet = fleet
    
    for i in range(iterations):
    
        game = Game(False,False)
        
        
        strategy = [game.random_strategy, game.sequential_strategy, game.mcts ]
        player_1_strategy = strategy[strategy_1]
        player_0_strategy = strategy[strategy_0]

        while not game.game_over_state:

            index = player_1_strategy() if game.turn else player_0_strategy()
            r = game.move(index)
            if r == -1: game.game_over_state = True  

        iteration_result = {
            'test' : i,
            'player_1_win' : 1 if game.winner == "Player 1" else 0,
            'player_0_win' : 1 if game.winner == "Player 2" else 0,
            'steps' : game.total_hits + game.total_miss,
            'miss' : game.total_miss
        }

        result = result.append( iteration_result, ignore_index = True)

        if game.turn:
            player_1_wins += 1
        if not game.turn: 
            player_0_wins += 1 
            
        print(f"SUCCESS: Test {i+1}/{iterations} for grid size {grid_size}. Winner: {game.winner},",end='\r', flush=True)

    print('\n')
    return result

# %%
'''
Use following codes for different strategies
0 : Random
1 : Sequential
2 : MCTS
'''


test_runs = 100
test_grid_sizes = [5,7,10,20]
test_fleet_sizes = [[2,3,4], [2,3,3,4], [2,3,3,4,5], [2,3,3,4,4,5]]
sim_results = pd.DataFrame(columns=['test', 'grid', 'player_1_wins', 'player_0_wins', 'avg_steps','avg_miss'])


for t, i in enumerate(zip(test_grid_sizes,test_fleet_sizes)):
    r = run_simulation(test_runs, i[0],i[1], 1, 2)
    sim_r = {
        'test' : t,
        'grid' : i[0],
        'player_1_wins' : r.player_1_win.astype(bool).sum(axis=0),
        'player_0_wins' : r.player_0_win.astype(bool).sum(axis=0),
        'avg_steps' : r.steps.mean(),
        'avg_miss' : r.miss.mean()
    }
    
    sim_results = sim_results.append(sim_r,ignore_index=True)
    
    
print(f"Simulation Complete. Ran {test_runs} iterations each for {t+1} test case ")
# Out:
# SUCCESS: Test 20/100 for grid size 5. Winner: Player 2,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_d/8kjzjzcx01346wv0l8cjr6180000gn/T/ipykernel_1212/725030237.py in <module>
#      14
#      15 for t, i in enumerate(zip(test_grid_sizes,test_fleet_sizes)):
# ---> 16     r = run_simulation(test_runs, i[0],i[1], 1, 2)
#      17     sim_r = {
#      18         'test' : t,
#
# /var/folders/_d/8kjzjzcx01346wv0l8cjr6180000gn/T/ipykernel_1212/1386383492.py in run_simulation(iterations, grid_size, fleet, strategy_1, strategy_0)
#       9     for i in range(iterations):
#      10
# ---> 11         game = Game(False,False)
#      12
#      13
#
# /Volumes/Jugen's T7 for School 1/Uni/CIS 667/Project/game_physics.py in __init__(self, human_player_1, human_player_0)
#     131
#     132         self.player_0 = Player(s.ship_sizes)
# --> 133         self.player_1 = Player(s.ship_sizes)
#     134
#     135         # Player 0 is False and Player 1 is True\
#
# /Volumes/Jugen's T7 for School 1/Uni/CIS 667/Project/game_physics.py in __init__(self, fleet)
#      72         self.hit_ships = [] # Coordinates of successful hits
#      73
# ---> 74         self.arrange_ships(sizes = fleet)
#      75
#      76         self.ships_coords = [s.index for s in self.ships]
#
# /Volumes/Jugen's T7 for School 1/Uni/CIS 667/Project/game_physics.py in arrange_ships(self, sizes)
#     100
#     101             while not valid_position:
# --> 102                 ship = Ship(s)
#     103
#     104                 # Check if the indexes generated intersect with another placed ship
#
# /Volumes/Jugen's T7 for School 1/Uni/CIS 667/Project/game_physics.py in __init__(self, size)
#      22
#      23             if self.index:
# ---> 24                 self.ship_coords_2D = np.unravel_index(self.index, (s.GRID_SIZE,s.GRID_SIZE))
#      25                 self.ship_coords_2D = list(zip(self.ship_coords_2D[0], self.ship_coords_2D[1]))
#      26
#
# <__array_function__ internals> in unravel_index(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
sns.barplot(x=sim_results.grid, y=sim_results.avg_steps)

# %%
sim_results
# Out:
#   test  grid player_1_wins player_0_wins avg_steps avg_miss
# 0  0.0   5.0           0.0          10.0      18.8      6.8
# 1  1.0   7.0           0.0          10.0      17.2      5.2
# 2  2.0  10.0           2.0           8.0      17.4      5.4
# 3  3.0  20.0           2.0           8.0      17.9      5.9

# %%
r = run_simulation(20,5,[2,3,4], 1,2)
# Out:
# Running test 20/20 for grid size 5

# %%
r
# Out:
#    test player_1_win player_0_winmiss steps  miss  player_0_win
# 0     0            0              NaN    18   6.0           0.0
# 1     1            0              NaN    16   4.0           0.0
# 2     2            0              NaN    19   7.0           0.0
# 3     3            0              NaN    14   2.0           0.0
# 4     4            0              NaN    19   7.0           0.0
# 5     5            0              NaN    13   1.0           0.0
# 6     6            0              NaN    19   7.0           0.0
# 7     7            0              NaN    19   7.0           0.0
# 8     8            0              NaN    21   9.0           0.0
# 9     9            0              NaN    20   8.0           0.0
# 10   10            0              NaN    19   7.0           0.0
# 11   11            0              NaN    17   5.0           0.0
# 12   12            0              NaN    15   3.0           0.0
# 13   13            0              NaN    20   8.0           0.0
# 14   14            0              NaN    20   8.0           0.0
# 15   15            0              NaN    18   6.0           0.0
# 16   16            0              NaN    19   7.0           0.0
# 17   17            0              NaN    19   7.0           0.0
# 18   18            0              NaN    16   4.0           0.0
# 19   19            0              NaN    19   7.0           0.0
